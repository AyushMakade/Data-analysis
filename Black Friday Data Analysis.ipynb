# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("BlackFriday.csv")

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 537572                          1               0                   1
# 537573                          1               0                   1
# 537574                          1               0                   8
# 537575                          1               0                   5
# 537576                          1               0                   5
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# 2                      NaN                 NaN      1422
# 3                     14.0                 NaN      1057
# 4                      NaN                 NaN      7969
# ...                    ...                 ...       ...
# 537572                 2.0                 NaN     11664
# 537573                15.0                16.0     19196
# 537574                15.0                 NaN      8043
# 537575                 NaN                 NaN      7172
# 537576                 8.0                 NaN      6875
#
# [537577 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 49.2+ MB

# %%
df.isnull()
# Out:
#         User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 0         False       False   False  False       False          False
# 1         False       False   False  False       False          False
# 2         False       False   False  False       False          False
# 3         False       False   False  False       False          False
# 4         False       False   False  False       False          False
# ...         ...         ...     ...    ...         ...            ...
# 537572    False       False   False  False       False          False
# 537573    False       False   False  False       False          False
# 537574    False       False   False  False       False          False
# 537575    False       False   False  False       False          False
# 537576    False       False   False  False       False          False
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                            False           False               False
# 1                            False           False               False
# 2                            False           False               False
# 3                            False           False               False
# 4                            False           False               False
# ...                            ...             ...                 ...
# 537572                       False           False               False
# 537573                       False           False               False
# 537574                       False           False               False
# 537575                       False           False               False
# 537576                       False           False               False
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                     True                True     False
# 1                    False               False     False
# 2                     True                True     False
# 3                    False                True     False
# 4                     True                True     False
# ...                    ...                 ...       ...
# 537572               False                True     False
# 537573               False               False     False
# 537574               False                True     False
# 537575                True                True     False
# 537576               False                True     False
#
# [537577 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
del df['Product_Category_2']
del df['Product_Category_3']
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 537572                          1               0                   1
# 537573                          1               0                   1
# 537574                          1               0                   8
# 537575                          1               0                   5
# 537576                          1               0                   5
#
#         Purchase
# 0           8370
# 1          15200
# 2           1422
# 3           1057
# 4           7969
# ...          ...
# 537572     11664
# 537573     19196
# 537574      8043
# 537575      7172
# 537576      6875
#
# [537577 rows x 10 columns]

# %%
for col in df.columns:
    print(col, '\t:', df[col].nunique(), '\t->', df[col].unique())
# Out:
# User_ID 	: 5891 	-> [1000001 1000002 1000003 ... 1004113 1005391 1001529]
# Product_ID 	: 3623 	-> ['P00069042' 'P00248942' 'P00087842' ... 'P00038842' 'P00295642'
#  'P00091742']
# Gender 	: 2 	-> ['F' 'M']
# Age 	: 7 	-> ['0-17' '55+' '26-35' '46-50' '51-55' '36-45' '18-25']
# Occupation 	: 21 	-> [10 16 15  7 20  9  1 12 17  0  3  4 11  8 19  2 18  5 14 13  6]
# City_Category 	: 3 	-> ['A' 'C' 'B']
# Stay_In_Current_City_Years 	: 5 	-> ['2' '4+' '3' '1' '0']
# Marital_Status 	: 2 	-> [0 1]
# Product_Category_1 	: 18 	-> [ 3  1 12  8  5  4  2  6 14 11 13 15  7 16 18 10 17  9]
# Purchase 	: 17959 	-> [ 8370 15200  1422 ... 14539 11120 18426]

# %% [markdown]
# ## Gender Ratio Pie Chart

# %%
df.groupby('Gender').size().plot(kind = 'pie', autopct = '%.1f%%', title = 'Gender Ratio', figsize = (6,6))
# Out:
# <Axes: title={'center': 'Gender Ratio'}>

# %%
df_pr = df.groupby('Gender').mean()['Purchase']
plt.style.use('ggplot')
plt.pie(df_pr, labels = ['Female', 'Male'], colors = ['g','c'], autopct='%.1f%%', shadow=True)
plt.axis('equal')
plt.legend()
plt.title('Gender Ratio')
plt.show()
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_10148\1082540868.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_pr = df.groupby('Gender').mean()['Purchase']

# %% [markdown]
# ## Gender Ratio Bar Graph

# %%
df.groupby('Gender').size().plot(kind = 'bar', figsize = (6,6))
# Out:
# <Axes: xlabel='Gender'>

# %% [markdown]
# ## Relation between gender and purchase

# %%
df.groupby('Gender').sum()['Purchase'].plot(kind = 'pie', autopct = "%0.1f%%")
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_10148\3323285997.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Gender').sum()['Purchase'].plot(kind = 'pie', autopct = "%0.1f%%")
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ## Relation between gender and purchase on average

# %%
df.groupby('Gender').mean()['Purchase']
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_10148\1042076743.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Gender').mean()['Purchase']
# Gender
# F    8809.761349
# M    9504.771713
# Name: Purchase, dtype: float64

# %%
df.groupby('Gender').mean()['Purchase'].plot(kind = 'pie', autopct = "%0.1f%%")
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_10148\3032596597.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Gender').mean()['Purchase'].plot(kind = 'pie', autopct = "%0.1f%%")
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ## Purchase Distribution by Age

# %%
df.groupby('Age').size().plot(kind = 'bar', figsize = (12, 6), title = 'Purchase Distribution by Age')
# Out:
# <Axes: title={'center': 'Purchase Distribution by Age'}, xlabel='Age'>

# %% [markdown]
# ## Unique products purchased by different age group

# %%
lst = []
for i in df['Age'].unique():
    lst.append([i, df[df['Age'] == i]['Product_ID'].nunique()])
    
data = pd.DataFrame(lst , columns = ['Age','Products'])
data.plot.bar(x = 'Age', figsize = (8,6))
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# ## Total amount spent by different age group

# %%
df.groupby('Age').sum()['Purchase'].plot(kind = 'bar', figsize = (12, 6), title = 'Amount Spend by Age')
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_10148\1062827794.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').sum()['Purchase'].plot(kind = 'bar', figsize = (12, 6), title = 'Amount Spend by Age')
# <Axes: title={'center': 'Amount Spend by Age'}, xlabel='Age'>

# %% [markdown]
# ## Mean amount spent by different age group - Bar Graph

# %%
df.groupby('Age').mean()['Purchase'].plot(kind = 'bar', figsize = (12, 6), title = 'Amount Spend by Age')
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_10148\3557190522.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').mean()['Purchase'].plot(kind = 'bar', figsize = (12, 6), title = 'Amount Spend by Age')
# <Axes: title={'center': 'Amount Spend by Age'}, xlabel='Age'>

# %% [markdown]
# ## Mean amount spent by different age group - Pie Chart

# %%
df.groupby('Age').mean()['Purchase'].plot(kind = 'pie', autopct = '%0.1f%%')
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_10148\1382529400.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').mean()['Purchase'].plot(kind = 'pie', autopct = '%0.1f%%')
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ## Marital Status Pie Chart

# %%
df.groupby('Marital_Status').size().plot(kind = 'pie', autopct = '%0.1f')
# Out:
# <Axes: >
