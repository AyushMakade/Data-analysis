# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('gdp.csv')
df
# Out:
#       Country Name Country Code  Year         Value
# 0       Arab World          ARB  1968  2.576068e+10
# 1       Arab World          ARB  1969  2.843420e+10
# 2       Arab World          ARB  1970  3.138550e+10
# 3       Arab World          ARB  1971  3.642691e+10
# 4       Arab World          ARB  1972  4.331606e+10
# ...            ...          ...   ...           ...
# 11502     Zimbabwe          ZWE  2012  1.424249e+10
# 11503     Zimbabwe          ZWE  2013  1.545177e+10
# 11504     Zimbabwe          ZWE  2014  1.589105e+10
# 11505     Zimbabwe          ZWE  2015  1.630467e+10
# 11506     Zimbabwe          ZWE  2016  1.661996e+10
#
# [11507 rows x 4 columns]

# %%
df['Country Name'].nunique(dropna = True)
# Out:
# 256

# %%
len(df[df['Country Name'] == 'India'])
# Out:
# 57

# %%
result = df.loc[df['Year'] == 1969, 'Value'].sum()
result
# Out:
# 19577200379601.25

# %%
gdp_in_1969 = 0
for i in df['Year']:
    if(df['Year'] == 1969):
        gdp_in_1969 += df['Value']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 3
#       1 gdp_in_1969 = 0
#       2 for i in df['Year']:
# ----> 3     if(df['Year'] == 1969):
#       4         gdp_in_1969 += df['Value']
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
total = df[['Value']].sum(axis=1).where(df['Year'] == 1969, 0)
total.sum()
# Out:
# 19577200379601.25

# %%
df_pr = df[df["Country Name"] == 'India']
i = df_pr[df_pr["Year"] == 1964].values
prev = df_pr[i-1][3]
cur = df_pr[i][3]
gdp_growth_1994 = round(((cur - prev) / prev)*100,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 3
#       1 df_pr = df[df["Country Name"] == 'India']
#       2 i = df_pr[df_pr["Year"] == 1964].values
# ----> 3 prev = df_pr[i-1][3]
#       4 cur = df_pr[i][3]
#       5 gdp_growth_1994 = round(((cur - prev) / prev)*100,2)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
df[df['Country Name'] == 'World']
# Out:
#      Country Name Country Code  Year         Value
# 2249        World          WLD  1960  1.366680e+12
# 2250        World          WLD  1961  1.421790e+12
# 2251        World          WLD  1962  1.526960e+12
# 2252        World          WLD  1963  1.643750e+12
# 2253        World          WLD  1964  1.800800e+12
# 2254        World          WLD  1965  1.961780e+12
# 2255        World          WLD  1966  2.128450e+12
# 2256        World          WLD  1967  2.264600e+12
# 2257        World          WLD  1968  2.443220e+12
# 2258        World          WLD  1969  2.690800e+12
# 2259        World          WLD  1970  2.957800e+12
# 2260        World          WLD  1971  3.266910e+12
# 2261        World          WLD  1972  3.767670e+12
# 2262        World          WLD  1973  4.591350e+12
# 2263        World          WLD  1974  5.296030e+12
# 2264        World          WLD  1975  5.897210e+12
# 2265        World          WLD  1976  6.416470e+12
# ...
